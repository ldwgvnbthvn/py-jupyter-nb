# %% [markdown]
# ctrl+enter untuk selesai edit markdown

# %% [markdown]
# __Bold Text__

# %% [markdown]
# _Italics Text_

# %% [markdown]
# Contoh <br>
# line break <br>
# tinggal <br>
# ketik <br>
# br pakai kurung siku <br>
# di belakang barisnya <br>

# %% [markdown]
# # Title
# ## Heading 1
# ### Heading 2
# #### Heading 3
# ##### Heading 4 <br>
# Note: jangan lupa kasih spasi setelah pagar2nya

# %% [markdown]
# <font color=red>The text to be show in red</font> <br>
# <font color=orange>The text to be show in orange</font> <br>
# <font color=yellow>The text to be show in yellow</font> <br>
# <font color=green>The text to be show in green</font> <br>
# <font color=blue>The text to be show in blue</font> <br>
# <font color=pink>The text to be show in pink</font> <br>

# %% [markdown]
# Sebelum horizontal separator
# ***
# Sesudah horizontal separator

# %% [markdown]
# # Contoh lokasi internal links <br>
# <a id="contohinlink"></a>

# %% [markdown]
# 1. Contoh
# 2. Numbered
# 3. Text
#     1. Tuh
#     2. Begini
#         1. Tab
#         2. Buat sub numbering
# 4. Gitu

# %% [markdown]
# > Contoh text indentation
#
# teks biasa pembanding <br>
# *btw pisahin antara yg indentation sama yg nggak bisa pake enter 2x

# %% [markdown]
# `contoh monospace font` <br>
# `monospace tu kek text di notepad` <br>
# BTW simbol tanda kutipnya bukan yg ', tapi yg di bawahnya tilde <br>
# (sebelah kiri angka 1)

# %% [markdown]
# $x = y + z$ <br>
# $E = mc^2$

# %% [markdown]
# Contoh internal links: <br>
# [internal link](#contohinlink) <br>
# wadu kok gabisa ini T_T

# %% [markdown]
# Contoh External links: <br>
# [source cheat sheet ini] (https://medium.com/analytics-vidhya/the-jupyter-notebook-formatting-guide-873ab39f765e)

# %%
# insert embedded webpage (harus di block code, bukan markdown)
from IPython.display import IFrame
IFrame('https://imslp.org/wiki/Category:Beethoven,_Ludwig_van', width = 800, height = 450)
# Out:
#         <iframe
#             width="800"
#             height="450"
#             src="https://imslp.org/wiki/Category:Beethoven,_Ludwig_van"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
# How to embed YouTube video
from IPython.display import YouTubeVideo
YouTubeVideo('zlRRdGnzA00', width = 800, height = 500)
# 'kode ID video setelah v= di url yutubnya'

# %%
# Ganti THEME YAY
# Install themes: (ini udah termasuk anaconda jadi yaa yauda gausah)
#!pip install jupyterthemes

# %%
# Cara munculin list themesnya
# !jt -l
# Out:
# Available Themes:
#    chesterish
#    grade3
#    gruvboxd
#    gruvboxl
#    monokai
#    oceans16
#    onedork
#    solarizedd
#    solarizedl

# %%
# Cara apply theme [harus RESTART jupyter notebook]
# !jt -t oceans16
# Enable toolbar, filename, logo, kernel logo
# !jt -t oceans16 -T -N -kl

# %%
# Cara balikin ke theme ori
#!jt -r
